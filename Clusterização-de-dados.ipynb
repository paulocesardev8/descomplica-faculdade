# %% [markdown]
# <a href="https://colab.research.google.com/github/paulocesardev8/descomplica-faculdade/blob/main/Clusteriza%C3%A7%C3%A3o-de-dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

# Inicializar SparkSession

spark = SparkSession.builder.appName("ConfiguraçãoCluster").getOrCreate()

# Configuração de Caching
# Substituído 'dbfs:/caminho_para_dados.csv' por um caminho de arquivo local de exemplo
# A configuração de autoescalonamento do Databricks foi removida, pois não é aplicável neste ambiente.

df = spark.read.csv("/content/sample_data/california_housing_train.csv", header=True, inferSchema=True)

df.cache()

df.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |  -114.31|   34.19|              15.0|     5612.0|        1283.0|    1015.0|     472.0|       1.4936|           66900.0|
# |  -114.47|    34.4|              19.0|     7650.0|        1901.0|    1129.0|     463.0|         1.82|           80100.0|
# |  -114.56|   33.69|              17.0|      720.0|         174.0|     333.0|     117.0|       1.6509|           85700.0|
# |  -114.57|   33.64|              14.0|     1501.0|         337.0|     515.0|     226.0|       3.1917|           73400.0|
# |  -114.57|   33.57|              20.0|     1454.0|         326.0|     624.0|     262.0|        1.925|           65500.0|
# ...
