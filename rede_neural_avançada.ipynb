# %% [markdown]
# <a href="https://colab.research.google.com/github/paulocesardev8/descomplica-faculdade/blob/main/rede_neural_avan%C3%A7ada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import accuracy_score

# exemplo de avaliação da acurácia
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 0, 0, 1]
accuracy = accuracy_score(y_true, y_pred)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 0.8

# %%
from sklearn.metrics import confusion_matrix

# exemplo de avaliação da matriz de confusão
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 0, 0, 1]
conf_matrix = confusion_matrix(y_true, y_pred)
print("Matriz de confusão:")
print(conf_matrix)
# Out:
# Matriz de confusão:
# [[2 0]
#  [1 2]]

# %%
from sklearn.metrics import precision_score
# exemplo de avaliação da precisão
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 0, 0, 1]
precision = precision_score(y_true, y_pred)
print("Matriz de confusão:")
print("Precisão:", precision)
# Out:
# Matriz de confusão:
# Precisão: 1.0

# %%
from sklearn.metrics import recall_score
# exemplo de avaliação da revocação (recal)
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 0, 0, 1]
recall = recall_score(y_true, y_pred)
print("Revocação:", recall)
# Out:
# Revocação: 0.6666666666666666

# %%
from sklearn.metrics import f1_score
# exemplo de avaliação da F1-score
y_true = [0, 1, 1, 0, 1]
y_pred = [0, 1, 0, 0, 1]
f1= f1_score(y_true, y_pred)
print("F1-Score:", f1)
# Out:
# F1-Score: 0.8
