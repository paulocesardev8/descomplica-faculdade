# %% [markdown]
# <a href="https://colab.research.google.com/github/paulocesardev8/descomplica-faculdade/blob/main/atividade_pratica_cloud_computing_e_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dados de consumo de combustível
dados_combustivel = {
    'tipo_veiculo': [ 'SUV', 'Compacto', 'Sedan', 'Hatchback', 'SUV', 'Compacto'],
    'consumo': [9.5, 12.3, 10.1, 11.8, 8.7, 13.2]
}

# Criar o DataFrame a partir dos dados
df_combustivel = pd.DataFrame(dados_combustivel)

# Visualizar os dados
print(df_combustivel)

# Calcular a média de consumo por tipo de veículo
media_consumo = df_combustivel.groupby('tipo_veiculo')['consumo'].mean()

# Plotar um gráfico de barras com a média de consumo por tipo de veículo
plt.bar(media_consumo.index, media_consumo)
plt.xlabel('Tipo de Veículo')
plt.ylabel('Média de Consumo')
plt.title('Média de Consumo por Tipo de Veículo')
plt.show()
# Out:
#   tipo_veiculo  consumo
# 0          SUV      9.5
# 1     Compacto     12.3
# 2        Sedan     10.1
# 3    Hatchback     11.8
# 4          SUV      8.7
# 5     Compacto     13.2
